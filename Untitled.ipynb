# %%
import numpy as np
import pandas as pd 
import difflib
import sys
import folium
from folium import plugins

# %%
states_cases = pd.read_csv('./live/us-counties.csv')

# %%
counties_lat_lon = pd.read_csv('../COVID-19_Cases.csv')
counties_lat_lon = counties_lat_lon.filter(["Lat", "Long_", "Province_State","Admin2"], axis=1)
counties_lat_lon.rename(columns={"Lat": "latitude", "Long_": "longitude"})
counties_lat_lon.columns = ['latitude', 'longitude', 'state', 'county']
counties_lat_lon = counties_lat_lon[counties_lat_lon['state'] == 'Florida']
counties_lat_lon
# Out:
#       latitude  longitude    state      county
# 322  29.678665 -82.359282  Florida     Alachua
# 323  30.330601 -82.284675  Florida       Baker
# 324  30.265487 -85.621226  Florida         Bay
# 325  29.950797 -82.166116  Florida    Bradford
# 326  28.294095 -80.730910  Florida     Brevard
# ..         ...        ...      ...         ...
# 385  30.044130 -82.374974  Florida       Union
# 386  29.058589 -81.182633  Florida     Volusia
# 387  30.165489 -84.398952  Florida     Wakulla
# 388  30.642040 -86.169357  Florida      Walton
# 389  30.613593 -85.660025  Florida  Washington
#
# [68 rows x 4 columns]

# %%
# pd.set_option('display.max_rows', None)
fl = states_cases.filter(['date','county','state', 'cases', 'deaths'], axis=1)
fl = fl[fl['state'] == 'Florida']
fl = fl.groupby('county').aggregate('sum').reset_index()
fl = fl.sort_values(by='county')
fl
# Out:
#         county  cases  deaths
# 0      Alachua   8060    55.0
# 1        Baker   1467    12.0
# 2          Bay   6040   104.0
# 3     Bradford   1090     8.0
# 4      Brevard   8800   293.0
# ..         ...    ...     ...
# 63     Unknown   1669     0.0
# 64     Volusia  10789   239.0
# 65     Wakulla   1122    10.0
# 66      Walton   1952    25.0
# 67  Washington   1072    22.0
#
# [68 rows x 3 columns]

# %%
merged_data = counties_lat_lon.merge(fl, on="county")
merged_data
# Out:
#      latitude  longitude    state      county  cases  deaths
# 0   29.678665 -82.359282  Florida     Alachua   8060    55.0
# 1   30.330601 -82.284675  Florida       Baker   1467    12.0
# 2   30.265487 -85.621226  Florida         Bay   6040   104.0
# 3   29.950797 -82.166116  Florida    Bradford   1090     8.0
# 4   28.294095 -80.730910  Florida     Brevard   8800   293.0
# ..        ...        ...      ...         ...    ...     ...
# 62  30.044130 -82.374974  Florida       Union    935    14.0
# 63  29.058589 -81.182633  Florida     Volusia  10789   239.0
# 64  30.165489 -84.398952  Florida     Wakulla   1122    10.0
# 65  30.642040 -86.169357  Florida      Walton   1952    25.0
# 66  30.613593 -85.660025  Florida  Washington   1072    22.0
#
# [67 rows x 6 columns]

# %%
middle_lat = merged_data['latitude'].median()
middle_lon = merged_data['longitude'].median()
m = folium.Map(location=[middle_lat, middle_lon],titles = "Covid-19-Cases",zoom_start=5)

# convert to (n, 2) nd-array format for heatmap
points = merged_data[['latitude', 'longitude']].dropna().values
pointArrays = np.split(points, len(points))

# plot heatmap
cases = (merged_data['cases'] / 1000).to_list()

for point, case in zip(pointArrays, cases):
    plugins.HeatMap(point, radius=case).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#    latitude  longitude
# 0   25.7617   -80.1918
# 1   26.1901   -80.3659
# 2   26.7056   -80.0364
# 3   27.9904   -82.3018
# 4   29.1383   -80.9956
